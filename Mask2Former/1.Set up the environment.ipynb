# %% [markdown]
# # Set up the MMSegmentation environment

# %% [markdown]
# Run this code line by line in order to install and configure the MMCV and MMSegmentation environment.
# It is recommended to run the code in a [cloud GPU environment](https://featurize.cn?s=d7ce99f842414bfcaea5662a97581bd1):
# GPU RTX 3060, CUDA v11.3.

# %% [markdown]
# > Tip: When running the following code, if it stalls for a long time, you can restart the kernel and run it again.

# %% [markdown]
# ## Install Pytorch
#
# https://pytorch.org

# %%
# !pip3  install torch==1.10.1+cu113 torchvision==0.11.2+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 37.0 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 131.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu117
#     Uninstalling torch-1.13.1+cu117:
#       Successfully uninstalled torch-1.13.1+cu117
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu117
#     Uninstalling torchvision-0.14.1+cu117:
#       Successfully uninstalled torchvision-0.14.1+cu117
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 0.13.1+cu117 requires torch==1.13.1, but you have torch 1.10.1+cu113 which is incompatible.
# ...

# %%
import torch
torch.__version__
# Out:
# '1.10.1+cu113'

# %% [markdown]
# ## Install MMCV using MIM

# %%
# !pip install -U openmim
# !mim install mmengine
# !mim install mmcv==2.0.0
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 114.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 79.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 43.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 71.4 MB/s eta 0:00:00
# ...
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=12e661d053dfcbb801d0de599b9e541b9355585db6086b1358b1e71a3a47d7b2
#   Stored in directory: /home/featurize/.cache/pip/wheels/af/b6/a2/a364b906dd331168e6dee9a45141e39942fa94d087e6616881
# ...
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535316 sha256=31cc70aab36f7cd5d0676c6b3160dca2a25445b0d706416d32c4ecf57e2843bd
# ...

# %% [markdown]
# ## Install Other Packages

# %%
# !pip install opencv-python pillow matplotlib seaborn tqdm 'mmdet>=3.1.0' -i https://pypi.tuna.tsinghua.edu.cn/simple
# !pip install setuptools==59.5 prettytable
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 79.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 144.0 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 85.2 MB/s eta 0:00:00
# ...

# %%
pip install pytorch-lightning==1.9.5 -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 38.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.4/891.4 kB 42.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 进入主目录
import os
os.chdir('mmsegmentation')

# %% [markdown]
# ## Install MMSegmentation

# %%
# !pip install -v -e . --config-settings editable_mode=compat
# Out:
# Using pip 24.2 from /environment/miniconda3/envs/py38/lib/python3.8/site-packages/pip (python 3.8)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Obtaining file:///home/featurize/work/Mask2Former/mmsegmentation
#   Running command pip subprocess to install build dependencies
#   Using pip 24.2 from /environment/miniconda3/envs/py38/lib/python3.8/site-packages/pip (python 3.8)
#   Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
#     Link requires a different Python (3.8.20 not in: '>=3.9'): https://pypi.tuna.tsinghua.edu.cn/packages/21/df/7c6bb83dcb45b35dc35b310d752f254211cde0bcd2a35290ea6e2862b2a9/setuptools-75.4.0-py3-none-any.whl#sha256=b3c5d862f98500b06ffdf7cc4499b48c46c317d8d56cb30b5c8bce4d88f5c216 (from https://pypi.tuna.tsinghua.edu.cn/simple/setuptools/) (requires-python:>=3.9)
# ...

# %% [markdown]
# ## Check Installation Success

# %%
# 检查 Pytorch
import torch, torchvision
print('Pytorch ', torch.__version__)
print('CUDA ',torch.cuda.is_available())
# Out:
# Pytorch  1.10.1+cu113
# CUDA  True

# %%
# 检查 mmcv
import mmcv
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print('MMCV', mmcv.__version__)
print('CUDA', get_compiling_cuda_version())
print('Compiler version', get_compiler_version())
# Out:
# MMCV 2.0.0
# CUDA 11.3
# Compiler version GCC 9.3

# %%
# 检查 mmsegmentation
import mmseg
from mmseg.utils import register_all_modules
from mmseg.apis import inference_model, init_model
print('mmsegmentation', mmseg.__version__)
# Out:
# mmsegmentation 1.1.2

# %% [markdown]
# No error message means that the installation was successful.
